# %%
import os
from datetime import datetime

# create folder with today's date
today_str = datetime.today().strftime("%Y-%m-%d")
save_dir = os.path.join("/Users/kristineandersen/Desktop/Speciale/Thesis_project/saved_files", today_str)
os.makedirs(save_dir, exist_ok=True)

# %%
from CI_bootstrap_rev_cali import *
# Out:
# Working directory set to: /Users/kristineandersen/Desktop/Speciale
# md=3, lr=0.01, n_est=300, cv_mse=17.6367, best_iter≈295
# md=3, lr=0.01, n_est=800, cv_mse=17.3441, best_iter≈508
# md=3, lr=0.01, n_est=1500, cv_mse=17.2093, best_iter≈724
# md=3, lr=0.03, n_est=300, cv_mse=17.6172, best_iter≈184
# md=3, lr=0.03, n_est=800, cv_mse=17.4498, best_iter≈293
# md=3, lr=0.03, n_est=1500, cv_mse=17.4460, best_iter≈316
# md=3, lr=0.1, n_est=300, cv_mse=18.1893, best_iter≈103
# md=3, lr=0.1, n_est=800, cv_mse=18.1915, best_iter≈109
# md=3, lr=0.1, n_est=1500, cv_mse=18.1915, best_iter≈109
# md=3, lr=0.2, n_est=300, cv_mse=18.7518, best_iter≈77
# md=3, lr=0.2, n_est=800, cv_mse=18.7518, best_iter≈77
# md=3, lr=0.2, n_est=1500, cv_mse=18.7518, best_iter≈77
# md=3, lr=0.3, n_est=300, cv_mse=18.6853, best_iter≈33
# md=3, lr=0.3, n_est=800, cv_mse=18.6853, best_iter≈33
# md=3, lr=0.3, n_est=1500, cv_mse=18.6853, best_iter≈33
# md=4, lr=0.01, n_est=300, cv_mse=17.4967, best_iter≈285
# ...

# %%
file_path = os.path.join(save_dir, "daily_predictions_with_bootstrap_year_one.csv")

daily[["date", "predicted", "lower", "upper", "p_low", "p_mid", "p_high"]].to_csv(file_path, index=False)

# %% [markdown]
# NOTE: Restart kernel to delete memory

# %%
import os
from datetime import datetime

# create folder with today's date
today_str = datetime.today().strftime("%Y-%m-%d")
save_dir = os.path.join("/Users/kristineandersen/Desktop/Speciale/Thesis_project/saved_files", today_str)
os.makedirs(save_dir, exist_ok=True)

# %%
from CI_clusters_plot import *
# Out:
# Working directory set to: /Users/kristineandersen/Desktop/Speciale
# md=3, lr=0.01, n_est=300, cv_mse=17.6367, best_iter≈295
# md=3, lr=0.01, n_est=800, cv_mse=17.3441, best_iter≈508
# md=3, lr=0.01, n_est=1500, cv_mse=17.2093, best_iter≈724
# md=3, lr=0.03, n_est=300, cv_mse=17.6172, best_iter≈184
# md=3, lr=0.03, n_est=800, cv_mse=17.4498, best_iter≈293
# md=3, lr=0.03, n_est=1500, cv_mse=17.4460, best_iter≈316
# md=3, lr=0.1, n_est=300, cv_mse=18.1893, best_iter≈103
# md=3, lr=0.1, n_est=800, cv_mse=18.1915, best_iter≈109
# md=3, lr=0.1, n_est=1500, cv_mse=18.1915, best_iter≈109
# md=3, lr=0.2, n_est=300, cv_mse=18.7518, best_iter≈77
# md=3, lr=0.2, n_est=800, cv_mse=18.7518, best_iter≈77
# md=3, lr=0.2, n_est=1500, cv_mse=18.7518, best_iter≈77
# md=3, lr=0.3, n_est=300, cv_mse=18.6853, best_iter≈33
# md=3, lr=0.3, n_est=800, cv_mse=18.6853, best_iter≈33
# md=3, lr=0.3, n_est=1500, cv_mse=18.6853, best_iter≈33
# md=4, lr=0.01, n_est=300, cv_mse=17.4967, best_iter≈285
# ...

# %%
plot_existing_clusters_for_day(daily, res, idx=0)

# %%
file_path = os.path.join(save_dir, "daily_predictions_with_clusters_year_one.csv")

daily[["date", "n", "predicted", "lower", "upper", "p_low", "p_mid", "p_high"]].to_csv(file_path, index=False)
