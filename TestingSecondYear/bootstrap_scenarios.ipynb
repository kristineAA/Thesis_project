# %%
import os
from datetime import datetime

# create folder with today's date
today_str = datetime.today().strftime("%Y-%m-%d")
save_dir = os.path.join("/Users/kristineandersen/Desktop/Speciale/Thesis_project/saved_files", today_str)
os.makedirs(save_dir, exist_ok=True)

# %%
from CI_bootstrap_cali import *
# Out:
# Working directory set to: /Users/kristineandersen/Desktop/Speciale/Thesis_project
# md=3, lr=0.01, n_est=300, cv_mse=17.8873, best_iter≈293
# md=3, lr=0.01, n_est=800, cv_mse=17.2743, best_iter≈601
# md=3, lr=0.01, n_est=1500, cv_mse=17.0997, best_iter≈897
# md=3, lr=0.03, n_est=300, cv_mse=17.4684, best_iter≈220
# md=3, lr=0.03, n_est=800, cv_mse=17.1618, best_iter≈432
# md=3, lr=0.03, n_est=1500, cv_mse=17.1548, best_iter≈440
# md=3, lr=0.1, n_est=300, cv_mse=17.8957, best_iter≈146
# md=3, lr=0.1, n_est=800, cv_mse=17.8998, best_iter≈146
# md=3, lr=0.1, n_est=1500, cv_mse=17.8998, best_iter≈146
# md=3, lr=0.2, n_est=300, cv_mse=18.3401, best_iter≈63
# md=3, lr=0.2, n_est=800, cv_mse=18.3401, best_iter≈63
# md=3, lr=0.2, n_est=1500, cv_mse=18.3401, best_iter≈63
# md=3, lr=0.3, n_est=300, cv_mse=18.6507, best_iter≈51
# md=3, lr=0.3, n_est=800, cv_mse=18.6507, best_iter≈51
# md=3, lr=0.3, n_est=1500, cv_mse=18.6507, best_iter≈51
# ...

# %%
file_path = os.path.join(save_dir, "daily_predictions_with_bootstrap_year_two.csv")

daily.to_csv(file_path, index=False)

# %% [markdown]
# NOTE: Restart kernel to delete memory

# %%
import os
from datetime import datetime

# create folder with today's date
today_str = datetime.today().strftime("%Y-%m-%d")
save_dir = os.path.join("/Users/kristineandersen/Desktop/Speciale/Thesis_project/saved_files", today_str)
os.makedirs(save_dir, exist_ok=True)

# %%
from CI_clusters_plot import *
# Out:
# Working directory set to: /Users/kristineandersen/Desktop/Speciale/Thesis_project
# md=3, lr=0.01, n_est=300, cv_mse=17.8873, best_iter≈293
# md=3, lr=0.01, n_est=800, cv_mse=17.2743, best_iter≈601
# md=3, lr=0.01, n_est=1500, cv_mse=17.0997, best_iter≈897
# md=3, lr=0.03, n_est=300, cv_mse=17.4684, best_iter≈220
# md=3, lr=0.03, n_est=800, cv_mse=17.1618, best_iter≈432
# md=3, lr=0.03, n_est=1500, cv_mse=17.1548, best_iter≈440
# md=3, lr=0.1, n_est=300, cv_mse=17.8957, best_iter≈146
# md=3, lr=0.1, n_est=800, cv_mse=17.8998, best_iter≈146
# md=3, lr=0.1, n_est=1500, cv_mse=17.8998, best_iter≈146
# md=3, lr=0.2, n_est=300, cv_mse=18.3401, best_iter≈63
# md=3, lr=0.2, n_est=800, cv_mse=18.3401, best_iter≈63
# md=3, lr=0.2, n_est=1500, cv_mse=18.3401, best_iter≈63
# md=3, lr=0.3, n_est=300, cv_mse=18.6507, best_iter≈51
# md=3, lr=0.3, n_est=800, cv_mse=18.6507, best_iter≈51
# md=3, lr=0.3, n_est=1500, cv_mse=18.6507, best_iter≈51
# ...

# %%
plot_existing_clusters_for_day(
    daily=daily,
    res=res,
    idx=0,
    alpha=0.1,
    B=20000,
    bins=30,
    scenario_names=["very_low", "mid_low", "low", "mid", "high", "mid_high", "very_high"])

# %%
file_path = os.path.join(save_dir, "daily_predictions_with_clusters_year_two.csv")

daily.to_csv(file_path, index=False)
